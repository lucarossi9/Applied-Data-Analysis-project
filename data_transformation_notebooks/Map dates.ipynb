# %% [markdown]
# # Map dates

# %% [markdown]
# ### Motivation

# %% [markdown]
# The idea explained in the readme needs for each quote the corresponding dates. Since the dates are not present in the standard Quotes dataset (we have just the date of the first occurrence for each quote) we will use the Quotebank article centric dataset to recover all the dates corresponding to the filtered quotes. This is the aim of the following notebook.

# %% [markdown]
# The procedure will consist in the following steps:
# - We filter the Quotebank (article centric) dataset keeping rows of the chunks corresponding to the articles which contained a quote containing the words Trump or Clinton.
# - We then read the file created in the notebook filter_quotes containing all the quotes (from the quotes centric data) containing the word Trump. We call this dataframe df_Trump for the sake of simplicity (already done in the Filter quotes notebook)
# - We look for the quoteID corresponding to the above mentioned quote in the filtered Quotebank (article centric) dataset and we extract the date of the articles in which the quoteID appears.
# - We create a new row in the dataframe df_Trump containing a list of dates in which the quotation appears.
# - We will deal with empty list of dates.

# %%
import pandas as pd

# %% [markdown]
# ### Initial Mapping

# %% [markdown]
# This mapping allows to store the article dates information in a very compact way, which in turn allows for the merge of quotes to their respective dates.

# %%
def filter_dataframe(year):
# This function will be used to filter the dataset selecting the quotes of a given year containing a given word
# in a free text search fashion.

    list_df = []
    with pd.read_json("../data/quotebank-"+year+".json.bz2", lines=True,  chunksize = 10000, compression = 'bz2') as df_reader: #we read the 
        #Quotebank article centric dataset
        import concurrent.futures
        executor = concurrent.futures.ThreadPoolExecutor(30)
        for chunk in df_reader: #we read chunk by chunk in order not to store everything in memory
            executor.submit(filter_chunk, list_df, chunk)
        executor.shutdown()
            
    df = pd.concat(list_df) #we concatenate the dataframes together to obtain a unique one
    return df

# %%
def filtering_func(lst):
    """ we keep just the articles contaning the word Trump or Clinton"""
    final_lst = []
    for el in lst:
        if (("Trump" in el["quotation"]) or ("Clinton" in el["quotation"])):
            final_lst.append(el["quoteID"])
    return final_lst

def filter_chunk(list_df, chunk):
    chunk.drop(columns=["articleID", "phase", "title", "url", "articleLength", "names"], inplace=True) # we drop to save space in memory
    chunk.quotations = chunk.quotations.transform(lambda x: filtering_func(x))
    chunk = chunk[chunk["quotations"].str.len() > 0]
    list_df.append(chunk)  #we append it to the list of dataframes

# %% [markdown]
# Get the quoteID_date mapping for each year, and save the result

# %%
for i in range(2015, 2021):
    quoteID_date = filter_dataframe(str(i))
    quoteID_date.to_pickle('{}_quoteID_date.pkl'.format(i))

# %%
quoteID_cleaned = {str(2000 + i) : pd.read_pickle('../data/' + str(2000 + i) + '_quoteID_date.pkl') for i in range(15,21)}
quoteID_cleaned
# Out:
# {'2015':                                                  quotations  \
#  147       [2015-08-05-025201, 2015-08-05-055692, 2015-08...
#  185                  [2015-08-06-081642, 2015-08-06-061444]
#  243                  [2015-08-07-047067, 2015-08-07-046176]
#  257                                     [2015-08-07-100597]
#  667       [2015-08-19-099364, 2015-08-19-121637, 2015-08...
#  ...                                                     ...
#  10144325                                [2015-05-12-050394]
#  10144709                                [2015-07-15-021355]
#  10144886                                [2015-07-23-075404]
#  10144944                                [2015-07-27-056746]
#  10144971                                [2015-07-28-102216]
#
#                          date
#  147      2015-08-05 22:33:14
#  185      2015-08-06 17:46:00
#  243      2015-08-07 17:20:35
#  257      2015-08-07 20:46:40
#  667      2015-08-19 09:49:00
#  ...                      ...
#  10144325 2015-05-14 15:32:00
#  10144709 2015-07-15 01:15:03
#  10144886 2015-07-23 13:12:06
#  10144944 2015-07-27 14:05:00
#  10144971 2015-07-28 17:09:31
#
#  [80834 rows x 2 columns],
#  '2016':                                      quotations                date
#  18                          [2016-02-12-005256] 2016-02-12 00:00:48
#  19                          [2016-07-20-058030] 2016-07-20 17:02:56
#  37       [2016-07-21-131217, 2016-07-21-054842] 2016-07-21 05:00:37
#  73                          [2016-07-20-013607] 2016-07-22 03:18:52
#  76                          [2016-02-13-058090] 2016-02-15 03:30:33
#  ...                                         ...                 ...
#  6759467                     [2016-07-12-035119] 2016-07-12 12:00:07
#  6759570                     [2016-07-15-116712] 2016-07-18 08:45:28
#  6759598                     [2016-07-18-054510] 2016-07-19 13:40:46
#  6759618                     [2016-07-20-103391] 2016-07-20 00:59:00
#  6759621                     [2016-07-19-067791] 2016-07-19 22:31:00
#
#  [215517 rows x 2 columns],
#  '2017':                                       quotations                date
#  8                            [2017-02-01-063094] 2017-02-01 05:00:51
#  35                           [2017-09-25-151461] 2017-09-25 15:22:43
#  36                           [2017-01-31-018570] 2017-01-31 20:21:42
#  58        [2017-02-02-003385, 2017-02-02-007840] 2017-02-02 06:24:32
#  64                           [2017-02-04-007846] 2017-02-04 08:54:00
#  ...                                          ...                 ...
#  14191700  [2017-10-10-023430, 2017-10-10-030764] 2017-10-10 01:06:17
#  14191711                     [2017-10-10-013047] 2017-10-10 18:33:00
#  14191764                     [2017-10-10-030776] 2017-10-12 12:14:13
#  14191783                     [2017-10-13-031969] 2017-10-13 03:53:24
#  14191797                     [2017-10-13-145630] 2017-10-13 00:00:00
#
#  [365915 rows x 2 columns],
#  '2018':                                                  quotations  \
#  1                                       [2018-05-12-053687]
#  91                                      [2018-05-24-130941]
#  100                                     [2018-01-03-103796]
#  125                                     [2018-05-25-079726]
#  136                                     [2017-11-14-025878]
#  ...                                                     ...
#  16481093                                [2018-03-09-123660]
#  16481094                                [2018-02-28-069183]
#  16481098                                [2018-03-10-014003]
#  16481177                                [2018-03-13-100775]
#  16481218  [2018-03-15-146844, 2018-03-15-144117, 2018-03...
#
#                          date
#  1        2018-05-22 15:16:19
#  91       2018-05-24 19:02:18
#  100      2018-01-03 02:00:00
#  125      2018-05-25 11:42:00
#  136      2018-01-04 00:00:00
#  ...                      ...
#  16481093 2018-03-09 23:36:35
#  16481094 2018-02-28 15:30:51
#  16481098 2018-03-10 08:56:22
#  16481177 2018-03-13 21:24:43
#  16481218 2018-03-15 12:03:52
#
#  [428974 rows x 2 columns],
#  '2019':                                                  quotations  \
#  9                                       [2019-04-02-038330]
#  144                                     [2019-01-03-013472]
#  237                                     [2019-04-06-031221]
#  238                                     [2019-01-06-048895]
#  257                                     [2019-04-06-023306]
#  ...                                                     ...
#  17213810  [2017-07-12-019553, 2016-09-16-031479, 2019-01...
#  17213826             [2019-01-25-103759, 2019-01-25-044020]
#  17213829                                [2019-01-25-080201]
#  17213901             [2018-08-23-025149, 2019-01-30-023494]
#  17213907                                [2019-01-31-082577]
#
#                          date
#  9        2019-04-02 00:00:00
#  144      2019-01-03 23:27:00
#  237      2019-04-06 10:40:00
#  238      2019-01-06 12:38:31
#  257      2019-04-07 01:00:36
#  ...                      ...
#  17213810 2019-01-27 23:04:33
#  17213826 2019-01-28 15:49:12
#  17213829 2019-01-28 10:46:03
#  17213901 2019-01-30 20:01:13
#  17213907 2019-01-31 00:55:58
#
#  [514762 rows x 2 columns],
#  '2020':                                                 quotations                date
#  1                                      [2019-03-25-054542] 2020-02-17 00:00:00
#  9                                      [2020-02-18-082033] 2020-02-18 00:11:22
#  35                                     [2020-02-13-037918] 2020-02-18 00:00:00
#  38       [2020-01-02-030693, 2020-01-02-060856, 2020-01... 2020-01-02 14:33:10
#  47                                     [2018-05-09-022250] 2020-02-18 18:24:18
#  ...                                                    ...                 ...
#  4001450                                [2020-02-14-003099] 2020-02-14 18:15:10
#  4001469                                [2020-02-14-049463] 2020-02-15 16:40:11
#  4001477             [2020-02-15-059128, 2020-02-15-004260] 2020-02-15 00:00:00
#  4001482                                [2020-02-15-044392] 2020-02-16 08:01:29
#  4001499                                [2020-02-15-056232] 2020-02-17 11:16:09
#
#  [131104 rows x 2 columns]}

# %% [markdown]
# ### Add dates to Trump and Clinton datasets

# %% [markdown]
# Update quotes from Trump and Clinton to convey all dates from all occurrences, and not just the first date.

# %%
# clinton_cleaned = pd.read_pickle('../data/df_Clinton_cleaned.pkl')
trump_cleaned = pd.read_pickle('../data/df_Trump_cleaned.pkl')

# clinton_cleaned
trump_cleaned
# Out:
#                    quoteID                                          quotation  \
# 12       2018-07-16-000103  [ Ensuring ] the orchestrating and timing of M...
# 66       2018-05-09-001003  300-plus years of them cold shoulders... Obama...
# 212      2018-08-02-002115  A politically connected contractor made a $500...
# 264      2018-08-19-001084  A Wider Danger: Trump's Troubling Attacks on J...
# 333      2018-09-26-004202  After the commercial, she says, `They told me ...
# ...                    ...                                                ...
# 5243994  2020-02-05-103219  Trump offends and disrespects the Venezuelan p...
# 5243995  2020-02-05-103235  Trump survived, but he is the most unpopular p...
# 5243996  2020-03-13-071475  Trump tried to mitigate the issue, saying it i...
# 5243997  2020-03-15-037086  Trump's do-over approach -- he unlocked $50 bi...
# 5244422  2020-02-20-097170  You have to accept some responsibility and ask...
#
#                      speaker         qids                date  numOccurrences  \
# 12         Corey Lewandowski  [Q20740735] 2018-07-16 14:05:34               2
# 66       Charlamagne Tha God  [Q16203002] 2018-05-09 11:00:00               1
# 212                     None           [] 2018-08-02 06:24:59               1
# 264                     None           [] 2018-08-19 02:05:39               3
# 333                     None           [] 2018-09-26 00:00:00               2
# ...                      ...          ...                 ...             ...
# 5243994        Jorge Arreaza   [Q6623799] 2020-02-05 00:00:00              11
# 5243995                 None           [] 2020-02-05 23:11:42               3
# 5243996     Hassan Nasrallah    [Q181182] 2020-03-13 22:15:06               1
# 5243997        Newt Gingrich    [Q182788] 2020-03-15 00:00:00              40
# 5244422       Pete Buttigieg   [Q7173106] 2020-02-20 03:50:07               2
#
#                                                     probas  \
# 12       [[Corey Lewandowski, 0.7179], [None, 0.2754], ...
# 66       [[Charlamagne Tha God, 0.4806], [None, 0.2924]...
# 212      [[None, 0.7942], [President Trump, 0.1406], [K...
# 264         [[None, 0.9052], [Queen Elizabeth II, 0.0948]]
# 333      [[None, 0.4595], [Tom Arnold, 0.3248], [Julie ...
# ...                                                    ...
# 5243994  [[Jorge Arreaza, 0.9164], [None, 0.0726], [Pre...
# 5243995           [[None, 0.8786], [Donald Trump, 0.1214]]
# 5243996  [[Hassan Nasrallah, 0.922], [None, 0.0741], [P...
# 5243997  [[Newt Gingrich, 0.5146], [None, 0.3958], [Don...
# 5244422  [[Pete Buttigieg, 0.3517], [Bernie Sanders, 0....
#
#                                                       urls phase
# 12       [http://www.theweek.co.uk/95082/donald-trump-s...     E
# 66       [https://www.portlandmercury.com/music/2018/05...     E
# 212      [https://sunlightfoundation.com/2018/08/02/tod...     E
# 264      [http://www.vnews.com/Forum-Aug-19-19549635, h...     E
# 333      [http://feeds.foxnews.com/~r/foxnews/entertain...     E
# ...                                                    ...   ...
# 5243994  [https://www.rawstory.com/2020/02/imwithfred-t...     E
# 5243995  [https://www.wellsvilledaily.com/zz/news/20200...     E
# 5243996  [http://israelnationalnews.com/News/News.aspx/...     E
# 5243997  [http://uspolitics.einnews.com/article/5120893...     E
# 5244422  [https://www.breitbart.com/2020-election/2020/...     E
#
# [470480 rows x 9 columns]

# %%
def filter_chunk_by_number_of_qids(initial_chunk, qid_number):
    """we select the quotes whose speaker has a single qid"""
    return initial_chunk[initial_chunk["qids"].str.len() == qid_number]

# %%
# clinton_cleaned= filter_chunk_by_number_of_qids(clinton_cleaned, 1)
trump_cleaned= filter_chunk_by_number_of_qids(trump_cleaned, 1)

# clinton_cleaned
trump_cleaned
# Out:
#                    quoteID                                          quotation  \
# 12       2018-07-16-000103  [ Ensuring ] the orchestrating and timing of M...
# 66       2018-05-09-001003  300-plus years of them cold shoulders... Obama...
# 366      2018-01-07-002036  All I can say is it's not a hoax. The Russians...
# 1024     2018-01-16-011608      being too nonchalant about Mr. Trump's rants.
# 1091     2018-09-24-011280  Brett Kavanaugh is poised to join Neil Gorsuch...
# ...                    ...                                                ...
# 5243971  2020-04-05-029136  To say that I'm infuriated with the recent act...
# 5243994  2020-02-05-103219  Trump offends and disrespects the Venezuelan p...
# 5243996  2020-03-13-071475  Trump tried to mitigate the issue, saying it i...
# 5243997  2020-03-15-037086  Trump's do-over approach -- he unlocked $50 bi...
# 5244422  2020-02-20-097170  You have to accept some responsibility and ask...
#
#                      speaker         qids                date  numOccurrences  \
# 12         Corey Lewandowski  [Q20740735] 2018-07-16 14:05:34               2
# 66       Charlamagne Tha God  [Q16203002] 2018-05-09 11:00:00               1
# 366           Lindsey Graham     [Q22212] 2018-01-07 15:40:00               1
# 1024            Floyd Abrams   [Q3365171] 2018-01-16 20:06:13               3
# 1091           Raul Labrador    [Q555393] 2018-09-24 23:21:10               1
# ...                      ...          ...                 ...             ...
# 5243971          Dwight Ball   [Q5318112] 2020-04-05 23:11:52               1
# 5243994        Jorge Arreaza   [Q6623799] 2020-02-05 00:00:00              11
# 5243996     Hassan Nasrallah    [Q181182] 2020-03-13 22:15:06               1
# 5243997        Newt Gingrich    [Q182788] 2020-03-15 00:00:00              40
# 5244422       Pete Buttigieg   [Q7173106] 2020-02-20 03:50:07               2
#
#                                                     probas  \
# 12       [[Corey Lewandowski, 0.7179], [None, 0.2754], ...
# 66       [[Charlamagne Tha God, 0.4806], [None, 0.2924]...
# 366      [[Lindsey Graham, 0.5251], [None, 0.2936], [Ch...
# 1024     [[Floyd Abrams, 0.7512], [None, 0.2421], [Hill...
# 1091     [[Raul Labrador, 0.6471], [None, 0.2436], [Pre...
# ...                                                    ...
# 5243971  [[Dwight Ball, 0.6293], [None, 0.3336], [Justi...
# 5243994  [[Jorge Arreaza, 0.9164], [None, 0.0726], [Pre...
# 5243996  [[Hassan Nasrallah, 0.922], [None, 0.0741], [P...
# 5243997  [[Newt Gingrich, 0.5146], [None, 0.3958], [Don...
# 5244422  [[Pete Buttigieg, 0.3517], [Bernie Sanders, 0....
#
#                                                       urls phase
# 12       [http://www.theweek.co.uk/95082/donald-trump-s...     E
# 66       [https://www.portlandmercury.com/music/2018/05...     E
# 366      [http://postandcourier.com/politics/would-lind...     E
# 1024     [http://www.washingtontimes.com/news/2018/jan/...     E
# 1091     [http://www.spokesman.com/stories/2018/sep/25/...     E
# ...                                                    ...   ...
# 5243971  [https://www.cbc.ca/news/politics/trudeau-will...     E
# 5243994  [https://www.rawstory.com/2020/02/imwithfred-t...     E
# 5243996  [http://israelnationalnews.com/News/News.aspx/...     E
# 5243997  [http://uspolitics.einnews.com/article/5120893...     E
# 5244422  [https://www.breitbart.com/2020-election/2020/...     E
#
# [215125 rows x 9 columns]

# %%
def years_to_try(year):
    """ outputs a list with years after the year received in the parameters """
    year_lst = [str(year)]
    for i in range(2020 - year):
        year_lst.append(str(year + i + 1))
    return year_lst

# %%
def refactor_row(row):
    """ refactor row to have all the dates found for every quote occurrence, instead of just the earliest date"""
    if row.numOccurrences > 1:
        quoteID = row.quoteID
        earliest_date = row.date
        occurrences_lst = []
        for year in years_to_try(earliest_date.year):
            dataframe = quoteID_cleaned[year]
            occurrences = dataframe[dataframe["quotations"].transform(lambda x: quoteID in x)].date.to_list() #we look for the quoteID of the quote
            # in the quoteID cleaned and we add the date to the list
            occurrences_lst += occurrences
            if len(occurrences_lst) == row.numOccurrences:
                break
        return occurrences_lst
    else:
        return [row.date] #if in the quotes data there is a single occurrence then we already have the date in the date column

# %%
def update_quotes(quotes, quoteID_cleaned):
    """ return quotes with all the dates found for every occurrence, instead of having just the earliest date"""
    new_quotes = quotes.copy()
    new_quotes["date"] = new_quotes.apply(lambda x: refactor_row(x), axis=1)
    return new_quotes

# %% [markdown]
# Get updated quotes with dates for Clinton and Trump.

# %%
# merged_quotes_clinton = update_quotes(clinton_cleaned, quoteID_cleaned)

merged_quotes_trump = update_quotes(trump_cleaned[:100], quoteID_cleaned)

# merged_quotes_clinton
merged_quotes_trump
# Out:
#                  quoteID                                          quotation  \
# 12     2018-07-16-000103  [ Ensuring ] the orchestrating and timing of M...
# 66     2018-05-09-001003  300-plus years of them cold shoulders... Obama...
# 366    2018-01-07-002036  All I can say is it's not a hoax. The Russians...
# 1024   2018-01-16-011608      being too nonchalant about Mr. Trump's rants.
# 1091   2018-09-24-011280  Brett Kavanaugh is poised to join Neil Gorsuch...
# ...                  ...                                                ...
# 24124  2018-12-21-099728  Today, at the direction of President Donald J....
# 24194  2018-11-17-059213  Trump deserves his choice, just like Obama des...
# 24198  2018-10-11-130960  Trump is exploiting Kanye West, who has admitt...
# 24202  2018-12-20-103345  Trump wanted $5 billion for a pointless border...
# 24205  2018-09-18-116071  Trump's protectionism is putting Republican me...
#
#                    speaker         qids  \
# 12       Corey Lewandowski  [Q20740735]
# 66     Charlamagne Tha God  [Q16203002]
# 366         Lindsey Graham     [Q22212]
# 1024          Floyd Abrams   [Q3365171]
# 1091         Raul Labrador    [Q555393]
# ...                    ...          ...
# 24124         Sonny Perdue    [Q525362]
# 24194          Megyn Kelly    [Q293260]
# 24198            Clay Cane  [Q27063054]
# 24202          Seth Meyers     [Q14536]
# 24205          Tony Fratto   [Q7822384]
#
#                                                     date  numOccurrences  \
# 12            [2018-07-17 06:00:00, 2018-07-16 14:05:34]               2
# 66                                 [2018-05-09 11:00:00]               1
# 366                                [2018-01-07 15:40:00]               1
# 1024          [2018-01-16 20:06:13, 2018-01-17 05:01:43]               3
# 1091                               [2018-09-24 23:21:10]               1
# ...                                                  ...             ...
# 24124  [2018-12-21 16:06:41, 2018-12-21 17:06:00, 201...               4
# 24194                              [2018-11-17 01:12:35]               1
# 24198                              [2018-10-11 20:03:38]               1
# 24202         [2018-12-20 16:30:03, 2018-12-20 15:02:47]               2
# 24205                              [2018-09-18 15:11:23]               1
#
#                                                   probas  \
# 12     [[Corey Lewandowski, 0.7179], [None, 0.2754], ...
# 66     [[Charlamagne Tha God, 0.4806], [None, 0.2924]...
# 366    [[Lindsey Graham, 0.5251], [None, 0.2936], [Ch...
# 1024   [[Floyd Abrams, 0.7512], [None, 0.2421], [Hill...
# 1091   [[Raul Labrador, 0.6471], [None, 0.2436], [Pre...
# ...                                                  ...
# 24124  [[Sonny Perdue, 0.9133], [None, 0.0842], [pres...
# 24194  [[Megyn Kelly, 0.7817], [None, 0.1646], [Presi...
# 24198  [[Clay Cane, 0.6559], [None, 0.2107], [Kanye W...
# 24202  [[Seth Meyers, 0.7962], [None, 0.187], [Sarah ...
# 24205  [[Tony Fratto, 0.8426], [None, 0.1475], [Presi...
#
#                                                     urls phase
# 12     [http://www.theweek.co.uk/95082/donald-trump-s...     E
# 66     [https://www.portlandmercury.com/music/2018/05...     E
# 366    [http://postandcourier.com/politics/would-lind...     E
# 1024   [http://www.washingtontimes.com/news/2018/jan/...     E
# 1091   [http://www.spokesman.com/stories/2018/sep/25/...     E
# ...                                                  ...   ...
# 24124  [http://qz.com/1504507/trumps-snap-food-stamps...     E
# 24194  [http://dailycaller.com/2018/07/10/megyn-kelly...     E
# 24198  [http://www.theweek.co.uk/97071/kanye-west-at-...     E
# 24202  [http://www.breitbart.com/politics/2018/12/20/...     E
# 24205  [https://www.nytimes.com/2018/09/18/business/e...     E
#
# [100 rows x 9 columns]

# %% [markdown]
# Unfortunately we cannot display the result of the cell above since we parallelized the work (one of us run the cell for Trump and the other for Clinton: the cell was taking a lot of time to be execute)

# %%
merged_quotes_clinton.to_pickle('../data/Clinton_with_dates.pkl')
merged_quotes_clinton.to_pickle('../data/Trump_with_dates.pkl')

# %% [markdown]
# ### Dealing with missing values

# %% [markdown]
# We notice some missing dates after we clean and merge every files. This happens because certain quotes are missing in the article files as explained in the notebook problems to report. In order to deal with this missing values, we will fill them with one date (the date contained in quoteID). We decided to fill it with a single date even if the number of the occurrences was bigger than one because normally the quote appears more times on different articles the same day (at most a few days after in most of the cases). Of course this is an approximation but we thought it was better to fill the missing values instead of dropping the corresponding rows.

# %%
def grab_date_from_quoteID(author_name, df):
    """this function is used to insert the date (taken from the quoteID when the above created list of Dates is empty"""
    df.loc[df["date"].str.len() == 0, "date"] = pd.to_datetime(df[(df["date"].str.len() == 0)]["quoteID"].str.slice(stop=10)).apply(lambda x: [x])
    return df

# %%
Clinton_with_dates = grab_date_from_quoteID("Clinton", Clinton_merged)
Trump_with_dates = grab_date_from_quoteID("Trump", Trump_merged)

# %%
Clinton_with_dates
# Out:
#                    quoteID                                          quotation  \
# 26       2015-10-25-000242  ' It is not now, nor has it ever been, the gol...
# 888      2015-09-16-006359  And I'm just pointing out the absurd on both s...
# 6930     2015-10-22-051493  If [ Democratic presidential candidate former ...
# 7374     2015-12-31-032035  I'm electable. I was elected in a purple state...
# 9855     2015-11-12-104266  The incentive to invent episodes of discrimina...
# ...                    ...                                                ...
# 5222109  2020-03-06-025712  I think that would have been a mistake, becaus...
# 5231803  2020-01-18-006266  Chief Justice Rehnquist, when he presided over...
# 5235860  2020-01-06-061256  The main difference between Lindsey and his De...
# 5235869  2020-04-09-052373  The model of Obama asking Bush and Clinton to ...
# 5237423  2020-01-22-037250  I think the fact is that Mitch keeps telling y...
#
#                    speaker         qids  numOccurrences  \
# 26          Bernie Sanders    [Q359442]               1
# 888       Kathleen Madigan   [Q6376814]               1
# 6930           Marco Rubio    [Q324546]               1
# 7374              Jeb Bush    [Q221997]               7
# 9855        Glenn Reynolds   [Q4392664]               2
# ...                    ...          ...             ...
# 5222109  Jennifer Palmieri  [Q18209402]               1
# 5231803        Dick Durbin    [Q434804]               1
# 5235860      David Woodard   [Q1177254]               6
# 5235869        Bill Haslam    [Q862186]               1
# 5237423      Patrick Leahy     [Q59315]              10
#
#                                                     probas  \
# 26       [[Bernie Sanders, 0.5395], [None, 0.3128], [Hi...
# 888           [[Kathleen Madigan, 0.8025], [None, 0.1975]]
# 6930     [[Marco Rubio, 0.93], [None, 0.0685], [Hillary...
# 7374     [[Jeb Bush, 0.8392], [None, 0.0925], [Hillary ...
# 9855     [[Glenn Reynolds, 0.3454], [Ed Driscoll, 0.322...
# ...                                                    ...
# 5222109  [[Jennifer Palmieri, 0.9117], [None, 0.056], [...
# 5231803  [[Dick Durbin, 0.898], [None, 0.079], [Charlie...
# 5235860  [[David Woodard, 0.7544], [None, 0.1797], [Lin...
# 5235869  [[Bill Haslam, 0.905], [None, 0.0837], [Barack...
# 5237423  [[Patrick Leahy, 0.8213], [None, 0.148], [Roge...
#
#                                                       urls phase  \
# 26       [http://examiner.com/article/bernie-sanders-sl...     E
# 888      [http://northjersey.com/arts-and-entertainment...     E
# 6930     [http://breitbart.com/video/2015/10/22/rubio-i...     E
# 7374     [http://www.postandcourier.com/article/2015123...     E
# 9855     [http://pjmedia.com/instapundit/218734/, http:...     E
# ...                                                    ...   ...
# 5222109  [https://www.rollingstone.com/politics/politic...     E
# 5231803  [https://www.washingtonexaminer.com/news/impea...     E
# 5235860  [http://chron.com/entertainment/article/How-Li...     E
# 5235869  [http://www.nytimes.com/2020/04/09/us/politics...     E
# 5237423  [http://wicz.com/story/41593610/inside-the-rep...     E
#
#                                                       date
# 26                                   [2015-10-25 14:12:35]
# 888                                  [2015-09-16 05:44:37]
# 6930                                 [2015-10-22 20:04:16]
# 7374                                 [2015-12-31 03:29:00]
# 9855                                 [2015-11-12 00:00:00]
# ...                                                    ...
# 5222109                              [2020-03-06 14:38:07]
# 5231803                              [2020-01-18 05:01:08]
# 5235860                              [2020-01-06 00:00:00]
# 5235869                              [2020-04-09 23:04:21]
# 5237423  [2020-01-22 08:45:29, 2020-01-23 05:13:15, 202...
#
# [62033 rows x 9 columns]

# %% [markdown]
# Save dataframes of Clinton and Trump

# %%
Clinton_with_dates.to_pickle('../data/Clinton_with_dates.pkl')
Trump_with_dates.to_pickle('../data/Trump_with_dates.pkl')
