# %%
import pandas as pd
import numpy as np

# %%
speaker_attributes = pd.read_parquet("data/speaker_attributes_updated.parquet")

speaker_attributes.head(12)
# Out:
#                                               aliases  \
# 0   [Washington, President Washington, G. Washingt...
# 1   [Douglas Noel Adams, Douglas Noël Adams, Dougl...
# 2       [Paul Marie Ghislain Otlet, Paul Marie Otlet]
# 3   [George Walker Bush, Bush Jr., Dubya, GWB, Bus...
# 4   [Velázquez, Diego Rodríguez de Silva y Velázqu...
# 5   [Augusto Pinochet Ugarte, Augusto José Ramón P...
# 6   [Baudelaire, Charles Pierre Baudelaire-Dufaÿs,...
# 7   [Mikołaj Kopernik, Nikolaus Kopernikus, Copern...
# 8   [Neil Percival Young, Shakey, Godfather of Gru...
# 9                                                None
# 10                                               None
# 11  [Gabriel González Videla, Gabriel Gonzales Vid...
#
#               date_of_birth                                nationality  \
# 0   [+1732-02-22T00:00:00Z]  [Great Britain, United States of America]
# 1   [+1952-03-11T00:00:00Z]                           [United Kingdom]
# ...

# %%
speaker_attributes.head(2)
# Out:
#                                              aliases            date_of_birth  \
# 0  [Washington, President Washington, G. Washingt...  [+1732-02-22T00:00:00Z]
# 1  [Douglas Noel Adams, Douglas Noël Adams, Dougl...  [+1952-03-11T00:00:00Z]
#
#                                  nationality  gender   lastrevid  \
# 0  [Great Britain, United States of America]  [male]  1395141751
# 1                           [United Kingdom]  [male]  1395737157
#
#       ethnic_group US_congress_bio_ID  \
# 0             None            W000178
# 1  [White British]               None
#
#                                           occupation  \
# 0  [politician, military officer, farmer, cartogr...
# 1  [playwright, screenwriter, novelist, children'...
#
#                       party academic_degree   id              label  \
# 0  [independent politician]            None  Q23  George Washington
# 1                      None            None  Q42      Douglas Adams
#
# ...

# %%
speaker_attributes.columns[5]
# Out:
# 'ethnic_group'

# %%
speaker_attributes.ethnic_group.unique
# Out:
# <bound method Series.unique of 0                     None
# 1          [White British]
# 2                     None
# 3                     None
# 4                     None
#                 ...
# 9055976               None
# 9055977               None
# 9055978               None
# 9055979               None
# 9055980               None
# Name: ethnic_group, Length: 9055981, dtype: object>

# %%
ethnicities = speaker_attributes.ethnic_group
ethnicities
# Out:
# 0                     None
# 1          [White British]
# 2                     None
# 3                     None
# 4                     None
#                 ...
# 9055976               None
# 9055977               None
# 9055978               None
# 9055979               None
# 9055980               None
# Name: ethnic_group, Length: 9055981, dtype: object

# %%
lst = []
for i in ethnicities:
    if np.any(i not in lst):
        lst.append(i)
print(lst)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-145-0881d4c9ac74> in <module>
#       1 lst = []
#       2 for i in ethnicities:
# ----> 3     if np.any(i not in lst):
#       4         lst.append(i)
#       5 print(lst)
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
#Test with nationality

nat = speaker_attributes.nationality.values
nat
# Out:
# array([array(['Great Britain', 'United States of America'], dtype=object),
#        array(['United Kingdom'], dtype=object),
#        array(['Belgium'], dtype=object), ..., None, None,
#        array(['United States of America'], dtype=object)], dtype=object)

# %% [markdown]
# #Prepare for plotting
